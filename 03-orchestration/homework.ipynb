# %% [markdown]
# # Q1
# ![image.png](attachment:32d62768-cfc8-4acf-8dc4-23b8a67996a5.png)

# %% [markdown]
# ## Answer

# %% [markdown]
# ![image.png](attachment:ea460183-774e-4c38-9821-d454e6ecd18d.png)
# v0.9.71

# %%
# !docker exec -it mlops-magic-platform-1 sh -c "pip show mage-ai"
# Out:
# Name: mage-ai
# Version: 0.9.71
# Summary: Mage is a tool for building and deploying data pipelines.
# Home-page: https://github.com/mage-ai/mage-ai
# Author: Mage
# Author-email: eng@mage.ai
# License:
# Location: /usr/local/lib/python3.10/site-packages
# Requires: aiofiles, alembic, bcrypt, croniter, cryptography, dask, datadog, Faker, freezegun, GitPython, great-expectations, httpx, inflection, ipykernel, ipython, itsdangerous, Jinja2, joblib, jupyter-client, jupyter-server, jupyter-server-proxy, ldap3, memory-profiler, newrelic, numpy, pandas, Pillow, polars, protobuf, psutil, pyarrow, PyGithub, PyJWT, python-dateutil, pytz, pyyaml, redis, requests, ruamel.yaml, scikit-learn, sentry-sdk, simplejson, six, sqlalchemy, sqlglot, terminado, thefuzz, tornado, typer, typing-extensions, watchdog
# Required-by:
#
# What's next?
#   Try Docker Debug for seamless, persistent debugging tools in any container or image → docker debug mlops-magic-platform-1
# ...

# %% [markdown]
# # Q2
#
# ![image.png](attachment:76127035-a7f9-46ac-aa99-1eb53ef2e257.png)

# %% [markdown]
# ## Answer

# %%
# !cat mlops/mlops/homework_03/homework_03/metadata.yaml | wc -l
# Out:
# 55

# %% [markdown]
# # Q3
# ![image.png](attachment:a476f22c-5089-4ca0-8d7f-723d8e027344.png)

# %% [markdown]
# ## Answer
# ![image.png](attachment:1bbb642c-0ed5-489b-a3ee-d8bbb9050a5c.png)

# %% [markdown]
# ## Q4
# ![image.png](attachment:97d845b2-78ce-4a00-8a3a-1b5708e58383.png)

# %% [markdown]
# ## Answer
# ![image.png](attachment:3c655639-9e50-4a5b-a03d-834c8bd3e434.png)

# %% [markdown]
# # Q5
# ![image.png](attachment:eaa87721-ea3a-42bb-af7d-6c1f978c9226.png)

# %% [markdown]
# # Answer
# ![image.png](attachment:cc6b331b-3d9c-4b41-8429-db82e758ec07.png)

# %% [markdown]
# # Q6
# ![image.png](attachment:98eb2a20-2ad7-40db-81c1-c22f497e63df.png)

# %% [markdown]
# # Answer

# %% [markdown]
# ![image.png](attachment:b82bd767-1933-40c1-bf2c-733c50630b73.png)

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
run_id = '6eced201bdb846a08c628d6c2ad6009c'

model_size_bytes = eval(mlflow.get_run(run_id).to_dictionary()['data']['tags']['mlflow.log-model.history'].replace('null', 'None'))[0]['model_size_bytes']
model_size_bytes
# Out:
# 4500
